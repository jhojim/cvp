# %% [markdown]
# ## HOMEWORK 13

# %%
import os
import cv2
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]

# %%
# Load the training labels
root = 'data' # Path to the dataset location, e.g., '/data/janko/dataset/GTSRB'
data = pd.read_csv(os.path.join(root, 'Train.csv'))

# Number of training samples (amount of samples in data)
num_samples = 20000

# Show random data samples
for ii in range(15):
    # Get random index
    idx = np.random.randint(0, num_samples)
    # Load image
    path = os.path.join(root, data.iloc[idx]['Path'])
    
    img = cv2.imread(os.path.join(root, data.iloc[idx]['Path']))

    # Convert image to RGB
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    # Show image
    plt.subplot(3,5,ii+1), plt.imshow(img), plt.title(data.iloc[idx]['ClassId'])

# %%
# Extract class identifiers
ids = data['ClassId'].values

print(ids)
# Out:
# [20 20 20 ... 42 42 42]

# %%
from collections import Counter
hist = Counter(ids)

plt.bar(hist.keys(), hist.values()), plt.grid(True)
plt.xlabel('Traffic Sign ID'), plt.ylabel('Counts')
# Out:
# (Text(0.5, 0, 'Traffic Sign ID'), Text(0, 0.5, 'Counts'))

# %% [markdown]
# ### Questions

# %% [markdown]
# #### Do you consider the dataset to be balanced? If so, why? If not, why?
# - The dataset is not balanced, which is quite logical - since we took a random number of imgs of different classes

# %% [markdown]
# #### Are there any classes that are (significantly) over-represented or under-represeneted?
# - If the count of each class is approximately equal, then the dataset can be considered balanced. However, in our case, some classes are represented significantly more often than others, and the data set is unbalanced. Since some classes are underrepresented
